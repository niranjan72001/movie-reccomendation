# %%
import pandas as pd
import numpy as np
coloumn_names=['user id','movieId','rating','time']
d1=pd.read_csv(r"D:\ml-25m\ml-25m\rating 1.csv")
d1.head(50)
# Out:
#     userId  movieId  rating   timestamp
# 0        1      296     5.0  1147880044
# 1        1      306     3.5  1147868817
# 2        1      307     5.0  1147868828
# 3        1      665     5.0  1147878820
# 4        1      899     3.5  1147868510
# 5        1     1088     4.0  1147868495
# 6        1     1175     3.5  1147868826
# 7        1     1217     3.5  1147878326
# 8        1     1237     5.0  1147868839
# 9        1     1250     4.0  1147868414
# 10       1     1260     3.5  1147877857
# 11       1     1653     4.0  1147868097
# 12       1     2011     2.5  1147868079
# 13       1     2012     2.5  1147868068
# 14       1     2068     2.5  1147869044
# 15       1     2161     3.5  1147868609
# 16       1     2351     4.5  1147877957
# 17       1     2573     4.0  1147878923
# 18       1     2632     5.0  1147878248
# 19       1     2692     5.0  1147869100
# 20       1     2843     4.5  1147868891
# 21       1     3448     4.0  1147868480
# ...

# %%
pwd
# Out:
# 'C:\\Users\\ssmit'

# %%
d1.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %%
movie_names=pd.read_csv(r"D:\ml-25m\ml-25m\movies.csv")
movie_names.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
d1=pd.merge(d1,movie_names,on='movieId')
d1.head()
# Out:
#    userId  movieId  rating   timestamp                title  \
# 0       1      296     5.0  1147880044  Pulp Fiction (1994)
# 1       3      296     5.0  1439474476  Pulp Fiction (1994)
# 2       4      296     4.0  1573938898  Pulp Fiction (1994)
# 3       5      296     4.0   830786155  Pulp Fiction (1994)
# 4       7      296     4.0   835444730  Pulp Fiction (1994)
#
#                         genres
# 0  Comedy|Crime|Drama|Thriller
# 1  Comedy|Crime|Drama|Thriller
# 2  Comedy|Crime|Drama|Thriller
# 3  Comedy|Crime|Drama|Thriller
# 4  Comedy|Crime|Drama|Thriller

# %%
#EDA
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
d1.groupby('title')['rating'].count().sort_values(ascending=False).head()
# Out:
# title
# Star Wars: Episode V - The Empire Strikes Back (1980)    5
# Pulp Fiction (1994)                                      5
# Star Wars: Episode IV - A New Hope (1977)                5
# Back to the Future (1985)                                4
# Star Wars: Episode VI - Return of the Jedi (1983)        4
# Name: rating, dtype: int64

# %%
d1.groupby('title')['rating'].mean().sort_values(ascending=False).head()
# Out:
# title
# Basketball Diaries, The (1995)    5.0
# Primal Fear (1996)                5.0
# Phenomenon (1996)                 5.0
# American Beauty (1999)            5.0
# Untouchables, The (1987)          5.0
# Name: rating, dtype: float64

# %%
net_rating=pd.DataFrame(d1.groupby('title')['rating'].mean())
net_rating.head()
# Out:
#                                                       rating
# title
# 102 Dalmatians (2000)                               2.000000
# 12 Angry Men (1957)                                 5.000000
# 15 Minutes (2001)                                   3.500000
# 2 Fast 2 Furious (Fast and the Furious 2, The) ...  4.000000
# 2001: A Space Odyssey (1968)                        4.333333

# %%
net_rating['no_ratings']=pd.DataFrame(d1.groupby('title')['rating'].count())
net_rating.head(15)
# Out:
#                                                       rating  no_ratings
# title
# 102 Dalmatians (2000)                               2.000000           1
# 12 Angry Men (1957)                                 5.000000           1
# 15 Minutes (2001)                                   3.500000           1
# 2 Fast 2 Furious (Fast and the Furious 2, The) ...  4.000000           1
# 2001: A Space Odyssey (1968)                        4.333333           3
# 2012 (2009)                                         2.500000           1
# 2046 (2004)                                         4.500000           1
# 21 Jump Street (2012)                               4.000000           1
# 22 Jump Street (2014)                               3.500000           2
# 25th Hour (2002)                                    4.500000           1
# 27 Dresses (2008)                                   3.000000           1
# 28 Days (2000)                                      3.000000           1
# ...

# %%
d1.groupby('title')['rating'].count()
net_rating['no_ratings'].hist(bins=70)#
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,10))#area of plot
net_rating['no_ratings'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,10))
net_rating['rating'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
movie_rec=d1.pivot_table(index='userId',columns='title',values='rating')
movie_rec.head()
# Out:
# title   102 Dalmatians (2000)  12 Angry Men (1957)  15 Minutes (2001)  \
# userId
# 1                         NaN                  NaN                NaN
# 2                         NaN                  NaN                NaN
# 3                         2.0                  NaN                3.5
# 4                         NaN                  NaN                NaN
# 5                         NaN                  NaN                NaN
#
# title   2 Fast 2 Furious (Fast and the Furious 2, The) (2003)  \
# userId
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     4.0
# 4                                                     NaN
# 5                                                     NaN
#
# title   2001: A Space Odyssey (1968)  2012 (2009)  2046 (2004)  \
# userId
# 1                                NaN          NaN          4.5
# ...

# %%
net_rating.sort_values('no_ratings',ascending=False).head(10)
# Out:
#                                                     rating  no_ratings
# title
# Star Wars: Episode IV - A New Hope (1977)            4.500           5
# Pulp Fiction (1994)                                  4.400           5
# Star Wars: Episode V - The Empire Strikes Back ...   4.600           5
# Lord of the Rings: The Two Towers, The (2002)        4.375           4
# Back to the Future (1985)                            3.250           4
# Pirates of the Caribbean: The Curse of the Blac...   4.125           4
# Raiders of the Lost Ark (Indiana Jones and the ...   4.000           4
# Toy Story (1995)                                     3.625           4
# Star Wars: Episode VI - Return of the Jedi (1983)    4.250           4
# Bourne Identity, The (2002)                          4.500           3

# %%
starwars_rating=movie_rec["Star Wars: Episode IV - A New Hope (1977)"]
starwars_rating.head()
# Out:
# userId
# 1    NaN
# 2    5.0
# 3    4.0
# 4    3.5
# 5    5.0
# Name: Star Wars: Episode IV - A New Hope (1977), dtype: float64

# %%
 similar_rec_starwars=movie_rec.corrwith(starwars_rating)
 similar_rec_starwars.head()
# Out:
# title
# 102 Dalmatians (2000)                                         NaN
# 12 Angry Men (1957)                                           NaN
# 15 Minutes (2001)                                             NaN
# 2 Fast 2 Furious (Fast and the Furious 2, The) (2003)         NaN
# 2001: A Space Odyssey (1968)                            -0.188982
# dtype: float64

# %%
corr_starwars=pd.DataFrame( similar_rec_starwars,columns=['correlation'])
corr_starwars.dropna(inplace=True)
corr_starwars.head()
# Out:
#                                 correlation
# title
# 2001: A Space Odyssey (1968)      -0.188982
# 22 Jump Street (2014)             -1.000000
# 40-Year-Old Virgin, The (2005)    -1.000000
# 9 (2009)                          -1.000000
# Alien (1979)                       1.000000

# %%
corr_starwars.sort_values('correlation',ascending=False).head()
# Out:
#                          correlation
# title
# Cowboys & Aliens (2011)          1.0
# Toy Story 2 (1999)               1.0
# Cars (2006)                      1.0
# V for Vendetta (2006)            1.0
# Lone Ranger, The (2013)          1.0

# %%
corr_starwars.join(net_rating[no_ratings])
corr_starwars.head()
# Out:
#                                 correlation  no_ratings
# title
# 2001: A Space Odyssey (1968)      -0.188982           3
# 22 Jump Street (2014)             -1.000000           2
# 40-Year-Old Virgin, The (2005)    -1.000000           2
# 9 (2009)                          -1.000000           2
# Alien (1979)                       1.000000           2

# %%
corr_starwars[corr_starwars['no_ratings']>4].sort_values('correlation',ascending=False).head()#change the number
# Out:
#                                                     correlation  no_ratings
# title
# Star Wars: Episode IV - A New Hope (1977)              1.000000           5
# Star Wars: Episode V - The Empire Strikes Back ...     0.968246           5
# Pulp Fiction (1994)                                   -0.188982           5
